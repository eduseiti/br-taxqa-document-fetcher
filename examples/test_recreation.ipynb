# %%
import os
import glob
import sys

# %%
# Ensure the repo root is in sys.path for imports.
# __file__ is not available in notebooks, so we probe the filesystem instead.
# Works whether Jupyter was started from the repo root or from examples/.
_cwd = os.getcwd()
for _candidate in [_cwd, os.path.dirname(_cwd)]:
    if os.path.exists(os.path.join(_candidate, 'legal_document_processor.py')):
        if _candidate not in sys.path:
            sys.path.insert(0, _candidate)
        break

# %%
WORKING_DIR = "/work/doutorado/artigos/RAG_evaluation/br-taxqa-document-fetcher"
# WORKING_DIR = "/work/temporal/recreate_br-tax-qa"

# %%
os.chdir(WORKING_DIR)

# %%
from legal_document_processor import LegalDocumentProcessor
from legal_document_fetcher_main import BRTaxQADocumentFetcher

# %%
# Initialize processor
processor = LegalDocumentProcessor('referred_legal_documents_QA_2024_v1.1.json')

# %%
laws = processor.process_documents()

# %%
# Filter laws with valid dates
laws_with_dates = processor.filter_laws_by_criteria(require_date=True)

# %%
len(laws_with_dates)

# %%
fetcher = BRTaxQADocumentFetcher(processor_instance=processor)

# %%
fetcher.setup_br_legal_fetcher()

# %% [markdown]
# ### Select some recent laws for testing

# %%
recent_laws = processor.filter_laws_by_criteria(
    min_year=2020,
    require_date=True
)

# %%
len(recent_laws)

# %%
processor.export_urls_list(recent_laws, 'recent_laws_urls.txt')

# %%
fetcher.fetch_documents_in_batches(recent_laws)

# %% [markdown]
# ### Run the process for everything, not just recent laws

# %%
results = fetcher.run_complete_process(
    require_date=True,
)

# %% [markdown]
# ### Retry downloading the failed documents

# %%
glob.glob("*.txt")
# Out:
# ['failed_urls_20260329_02.txt',
#  'failed_urls_20260312.txt',
#  'failed_urls_20260329_01.txt',
#  'leis_referenciadas_20260409.txt',
#  'failed_urls_20260319.txt',
#  'requirements.txt',
#  'failed_urls_20260319_fixed.txt',
#  'law_urls_with_dates.txt']

# %%
fetcher = BRTaxQADocumentFetcher(urls_file='leis_referenciadas_20260409.txt')

# %%
results = fetcher.run_complete_process(
    require_date=True,
)
# Out:
# LawDocument(filename='Lei 3071 from URL', number='3071', date='1916-01-01', year='1916', title='Lei nº 3071', urn='urn:lex:br:federal:lei:1916-01-01;3071', original_content='')
# LawDocument(filename='Lei 10406 from URL', number='10406', date='2002-01-10', year='2002', title='Lei nº 10406', urn='urn:lex:br:federal:lei:2002-01-10;10406', original_content='')
# LawDocument(filename='Lei 5869 from URL', number='5869', date='1973-01-11', year='1973', title='Lei nº 5869', urn='urn:lex:br:federal:lei:1973-01-11;5869', original_content='')
# LawDocument(filename='Lei 13105 from URL', number='13105', date='2015-03-16', year='2015', title='Lei nº 13105', urn='urn:lex:br:federal:lei:2015-03-16;13105', original_content='')
# Fetching documents:   0%|                                                                                                                 | 0/4 [00:00<?, ?it/s]2026-04-09 11:51:28,739 - legal_document_fetcher - INFO - Selenium WebDriver initialized successfully
# 2026-04-09 11:51:28,741 - legal_document_fetcher - INFO - Fetching with Selenium: https://normas.leg.br/?urn=urn:lex:br:federal:lei:1916-01-01;3071
# 2026-04-09 11:51:31,473 - legal_document_fetcher - INFO - Found sf-unstructured-legislation-viewer element
# 2026-04-09 11:51:31,562 - legal_document_fetcher - INFO - Extracted 1125474 bytes from shadow DOM
# 2026-04-09 11:51:31,575 - legal_document_fetcher - INFO - Successfully fetched 1241138 bytes with Selenium
# 2026-04-09 11:51:31,717 - legal_document_fetcher - INFO - Detected shadow DOM content marker
# 2026-04-09 11:51:31,833 - legal_document_fetcher - INFO - Found main content div in shadow DOM
# 2026-04-09 11:51:31,898 - legal_document_fetcher - INFO - Adding document title: CÓDIGO CIVIL DOS ESTADOS UNIDOS DO BRASIL...
# 2026-04-09 11:51:31,900 - legal_document_fetcher - INFO - Starting to add HTML content to document
# 2026-04-09 11:51:32,264 - legal_document_fetcher - INFO - Finished adding content. Document now has 3769 paragraphs
# 2026-04-09 11:51:32,290 - legal_document_fetcher - INFO - Saved document: fetched_documents/documents/lei_3071_19160101.docx
# 2026-04-09 11:51:32,290 - legal_document_fetcher - INFO - ✓ lei_3071_19160101 -> lei_3071_19160101.docx
# Fetching documents:  25%|██████████████████████████▎                                                                              | 1/4 [00:07<00:23,  7.89s/it]2026-04-09 11:51:34,294 - legal_document_fetcher - INFO - Fetching with Selenium: https://normas.leg.br/?urn=urn:lex:br:federal:lei:2002-01-10;10406
# 2026-04-09 11:51:54,491 - legal_document_fetcher - INFO - Shadow DOM element not found or timeout: Message:
# Stacktrace:
# #0 0x63eb927e340a <unknown>
# #1 0x63eb9221776b <unknown>
# #2 0x63eb92268e88 <unknown>
# #3 0x63eb922690c1 <unknown>
# #4 0x63eb922b72c4 <unknown>
# #5 0x63eb922b4760 <unknown>
# #6 0x63eb9225b7b2 <unknown>
# #7 0x63eb9225c461 <unknown>
# #8 0x63eb927abdf9 <unknown>
# #9 0x63eb927aed5d <unknown>
# #10 0x63eb92794b41 <unknown>
# #11 0x63eb927af93b <unknown>
# #12 0x63eb9277b870 <unknown>
# #13 0x63eb927d0828 <unknown>
# #14 0x63eb927d09fc <unknown>
# #15 0x63eb927e2763 <unknown>
# #16 0x71a412616ac3 <unknown>
#
# 2026-04-09 11:51:54,493 - legal_document_fetcher - INFO - Returning page source without shadow DOM content
# 2026-04-09 11:51:54,606 - legal_document_fetcher - INFO - Successfully fetched 1537862 bytes with Selenium
# 2026-04-09 11:51:54,944 - legal_document_fetcher - WARNING - Primary selector 'div.texto' failed, trying fallbacks
# 2026-04-09 11:51:54,945 - legal_document_fetcher - INFO - Found content with fallback selector: sf-legislation-articulation-text
# 2026-04-09 11:51:55,115 - legal_document_fetcher - INFO - Skipping title heading (generic or too long): Lei:PARTE GERALLIVRO IDAS PESSOASTÍTULO IDAS PESSOAS NATURAISCAPÍTULO IDA PERSONALIDADE E DA CAPACID...
# 2026-04-09 11:51:55,116 - legal_document_fetcher - INFO - Starting to add HTML content to document
# 2026-04-09 11:51:55,165 - legal_document_fetcher - INFO - Found image in paragraph, adding to document
# 2026-04-09 11:51:55,165 - legal_document_fetcher - INFO - Skipping external image URL: assets/img/court.svg
# 2026-04-09 11:51:55,311 - legal_document_fetcher - INFO - Found image in paragraph, adding to document
# 2026-04-09 11:51:55,312 - legal_document_fetcher - INFO - Skipping external image URL: assets/img/court.svg
# 2026-04-09 11:51:55,329 - legal_document_fetcher - INFO - Found image in paragraph, adding to document
# 2026-04-09 11:51:55,329 - legal_document_fetcher - INFO - Skipping external image URL: assets/img/court.svg
# 2026-04-09 11:51:55,772 - legal_document_fetcher - INFO - Finished adding content. Document now has 4755 paragraphs
# 2026-04-09 11:51:55,804 - legal_document_fetcher - INFO - Saved document: fetched_documents/documents/lei_10406_20020110_1.docx
# 2026-04-09 11:51:55,805 - legal_document_fetcher - INFO - ✓ lei_10406_20020110 -> lei_10406_20020110_1.docx
# Fetching documents:  50%|████████████████████████████████████████████████████▌                                                    | 2/4 [00:31<00:34, 17.08s/it]2026-04-09 11:51:57,809 - legal_document_fetcher - INFO - Fetching with Selenium: https://normas.leg.br/?urn=urn:lex:br:federal:lei:1973-01-11;5869
# 2026-04-09 11:51:58,480 - legal_document_fetcher - INFO - Found sf-unstructured-legislation-viewer element
# 2026-04-09 11:51:58,610 - legal_document_fetcher - INFO - Extracted 1353356 bytes from shadow DOM
# 2026-04-09 11:51:58,621 - legal_document_fetcher - INFO - Successfully fetched 1495404 bytes with Selenium
# 2026-04-09 11:51:58,865 - legal_document_fetcher - INFO - Detected shadow DOM content marker
# 2026-04-09 11:51:59,085 - legal_document_fetcher - INFO - Found main content div in shadow DOM
# 2026-04-09 11:51:59,260 - legal_document_fetcher - INFO - Adding document title: Seção I...
# 2026-04-09 11:51:59,262 - legal_document_fetcher - INFO - Starting to add HTML content to document
# 2026-04-09 11:51:59,667 - legal_document_fetcher - INFO - Finished adding content. Document now has 3610 paragraphs
# 2026-04-09 11:51:59,691 - legal_document_fetcher - INFO - Saved document: fetched_documents/documents/lei_5869_19730111.docx
# 2026-04-09 11:51:59,692 - legal_document_fetcher - INFO - ✓ lei_5869_19730111 -> lei_5869_19730111.docx
# Fetching documents:  75%|██████████████████████████████████████████████████████████████████████████████▊                          | 3/4 [00:35<00:11, 11.06s/it]2026-04-09 11:52:01,696 - legal_document_fetcher - INFO - Fetching with Selenium: https://normas.leg.br/?urn=urn:lex:br:federal:lei:2015-03-16;13105
# 2026-04-09 11:52:21,961 - legal_document_fetcher - INFO - Shadow DOM element not found or timeout: Message:
# Stacktrace:
# #0 0x63eb927e340a <unknown>
# #1 0x63eb9221776b <unknown>
# #2 0x63eb92268e88 <unknown>
# #3 0x63eb922690c1 <unknown>
# #4 0x63eb922b72c4 <unknown>
# #5 0x63eb922b4760 <unknown>
# #6 0x63eb9225b7b2 <unknown>
# #7 0x63eb9225c461 <unknown>
# #8 0x63eb927abdf9 <unknown>
# #9 0x63eb927aed5d <unknown>
# #10 0x63eb92794b41 <unknown>
# #11 0x63eb927af93b <unknown>
# #12 0x63eb9277b870 <unknown>
# #13 0x63eb927d0828 <unknown>
# #14 0x63eb927d09fc <unknown>
# #15 0x63eb927e2763 <unknown>
# #16 0x71a412616ac3 <unknown>
#
# 2026-04-09 11:52:21,963 - legal_document_fetcher - INFO - Returning page source without shadow DOM content
# 2026-04-09 11:52:22,059 - legal_document_fetcher - INFO - Successfully fetched 1375351 bytes with Selenium
# 2026-04-09 11:52:22,367 - legal_document_fetcher - WARNING - Primary selector 'div.texto' failed, trying fallbacks
# 2026-04-09 11:52:22,368 - legal_document_fetcher - INFO - Found content with fallback selector: sf-legislation-articulation-text
# 2026-04-09 11:52:22,527 - legal_document_fetcher - INFO - Skipping title heading (generic or too long): Lei:PARTE GERALLIVRO IDAS NORMAS PROCESSUAIS CIVISTÍTULO ÚNICODAS NORMAS FUNDAMENTAIS E DA APLICAÇÃO...
# 2026-04-09 11:52:22,527 - legal_document_fetcher - INFO - Starting to add HTML content to document
# 2026-04-09 11:52:22,542 - legal_document_fetcher - INFO - Found image in paragraph, adding to document
# 2026-04-09 11:52:22,543 - legal_document_fetcher - INFO - Skipping external image URL: assets/img/court.svg
# 2026-04-09 11:52:22,545 - legal_document_fetcher - INFO - Found image in paragraph, adding to document
# 2026-04-09 11:52:22,545 - legal_document_fetcher - INFO - Skipping external image URL: assets/img/court.svg
# 2026-04-09 11:52:22,546 - legal_document_fetcher - INFO - Found image in paragraph, adding to document
# 2026-04-09 11:52:22,546 - legal_document_fetcher - INFO - Skipping external image URL: assets/img/court.svg
# 2026-04-09 11:52:22,770 - legal_document_fetcher - INFO - Found image in paragraph, adding to document
# 2026-04-09 11:52:22,771 - legal_document_fetcher - INFO - Skipping external image URL: assets/img/court.svg
# 2026-04-09 11:52:22,921 - legal_document_fetcher - INFO - Found image in paragraph, adding to document
# 2026-04-09 11:52:22,922 - legal_document_fetcher - INFO - Skipping external image URL: assets/img/court.svg
# 2026-04-09 11:52:23,117 - legal_document_fetcher - INFO - Finished adding content. Document now has 4468 paragraphs
# 2026-04-09 11:52:23,146 - legal_document_fetcher - INFO - Saved document: fetched_documents/documents/lei_13105_20150316_1.docx
# 2026-04-09 11:52:23,146 - legal_document_fetcher - INFO - ✓ lei_13105_20150316 -> lei_13105_20150316_1.docx
# Fetching documents: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:56<00:00, 14.19s/it]
# 2026-04-09 11:52:23,220 - legal_document_fetcher - INFO - Selenium driver closed
# 2026-04-09 11:52:23,223 - legal_document_fetcher - INFO - Results exported to fetched_documents/metadata/fetch_results.csv

# %%
fetcher = BRTaxQADocumentFetcher(urls_file='failed_urls_20260329_02.txt')

# %%
results = fetcher.run_complete_process(
    require_date=True,
)
